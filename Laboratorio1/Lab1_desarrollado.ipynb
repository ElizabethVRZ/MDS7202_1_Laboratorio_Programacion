# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Primavera 2024</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Ignacio Meza, Sebastián Tinoco
# - Auxiliar: Eduardo Moya
# - Ayudantes: Nicolás Ojeda, Melanie Peña, Valentina Rojas

# %% [markdown]
# ### Equipo: **SUPER IMPORTANTE - notebooks sin nombre no serán revisados**
#
# - Nombre de alumno 1: Elizabeth Ramírez Zamorano

# %% [markdown]
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: 6 días de plazo con descuento de 1 punto por día. Entregas Jueves a las 23:59.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# ### **Link de repositorio de GitHub:** [https://github.com/ElizabethVRZ/Laboratorio_Programacion_Datos]

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2.5 pts)
#
# <p align="center">
#   <img src="https://cdn.thedesigninspiration.com/wp-content/uploads/sites/3/2019/04/macintosh-hdusersbrittanyloefflerdownloadsanig-1.gif" width="350">
# </p>

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Qué elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Qué comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# ### Respuestas
#
# **Respuesta 1**:
# En clases vimos que Git es un DVCS (Distributed Version Control System) que sirve para guardar proyectos con un sistema de control de versiones. Git permite tener un sistema en donde podemos hacer un seguimiento a las versiones que han ido cambiando a lo largo del tiempo. Para explicar en mayor detalle esto, expliquemos como funciona Git. Uno tendrá un repositorio, que es un conjunto de carpetas y archivos en el que se almacena el código de un proyecto más el historial de cambios de cada archivo. Git administra los registros a través de archivos en una carpeta oculta llamada ".git".
#
#
# **Respuesta 2**: a continuación se detallan 3 diferencias vistas en clases.
#
# Diferencia 1: Son distintos en su naturaleza, ya que Git es un software de sistema de control de versiones distribuido, mientras que Github es un servicio de alojamiento.
#
# Diferencia 2: Git es una línea de comando, que podríamos usarlo directamente en Git bash. En cambio, GitHub es una interfaz gráfica.
#
# Diferencia 3:  Git crea un repositorio local para hacer el seguimiento en los cambios locales, en cambio Github es un espacio para subir una copia de
# los repositorios de Git. Tener cuenta que uno podría subir archivos directos a Github, pero no es el uso ideal.
#
# **Respuesta 3**:
# Un hash es una cadena de caracteres (40 caracteres) que es el identificador único de elementos. En Git se uso hash SHA1. Un hash puede hacer referencia a un blob, un commit o un árbol. Cabe señalar que no es necesario usar los 40 caracteres, sino que bastan unos pocos para identificar por ejemplo un commit ( esto lo hicimos en clases).
#
# Con respecto a como se representa un hash en un commit,  al escribir git log en el terminal, aparecerá el historial de commit realizados a lo largo del tiempo. Cada commit tiene un hash. Si quiero volver a un commit anterior, podría volver a ese commit anterior por medio del hash, llamando a ese commit con unos 6 caracteres del hash del commit específico que quiero.
#
# **Respuesta 4**:
#
# Git tiene distintos elementos en su estructura.
#
# Primero, necesita un repositorio, que será una carpeta.
# El centro de mando de Git es una estructura de datos key-value. En ese núcleo o centro de mando quedan guardados los archivos del repositorio y rutas generados.
#
# Todo archivo que se guarde, quedará  guardado en un directorio o carpeta.
#
# Para ir en detalle a la estructura, en Git existen los blob, commit y tree. Explicaré en detalle cada uno.
# Los blob es donde se almacenan el contenido de un archivo. Al hacer cambios en un archivo, se genera un nuevo blob.
# Commit es una captura instantánea de archivos que estaban en un lugar llamado staging area.
#
# Un árbol es el directorio para blobs y más árboles. En la raíz siempre hay un árbol.
#
# Existen las ramas o branches, que es una réplica de la rama desde donde se originó. Podría trabajar en una rama y luego hacer un merge para unir cambios que hice en la rama.
#
# También, una parte importante en Git que mencione antes es el staging area, que es un conjunto de archivos modificados que aún no han sido aprobados para formar parte del repositorio ni de su registro de cambios (aún no se le hace un commit), pero que están a un paso de serlos.
#
# Finalmente, mencionar, que existe el repositorio local (en mi pc) y el repositorio remoto (repositorio en Github).
#
# **Respuesta 5**:
# Para crear un repositorio tengo dos opciones. Una sería crear un repositorio desde cero, esto se hace con el comando `git init`. Otra opción es clonar un repositorio, por ejemplo clonar el repositorio que hice en Github (esto hicimos en la clase), esto se hace con el comando `git clone` https del repositorio.
#
# Seguimiento en archivos:
#
# Primero, para ver el estado, podría usar `git status`, este comando me dirá si hay que hacer commit o no.
#
# Luego, para ver cambios a lo largo del tiempo, hay algunos comandos que vimos en clases.
# Con el comando `git log`, puedo ver el historial de commit. Una variante de `git log` es `git log -- all- graph` que usamos en clases.
# También podría usar `git diff` que permite ver diferencias entre conjuntos de archivos en el repositorio. Tambien esta el `git log --all --graph --decorate --oneline` que use en las partes de más abajo en la tarea y encontré que era super explicativo para ver cambios en el tiempo.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. `git status` genera los mismos resultados que `git log`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>
#
# **Respuesta 6**. F. Las colisiones o conflictos en una misma línea son debido a que dos personas trabajan en la misma línea y quieren unir las ramas. Estos "conflictos" se solucionan a mano y luego se deben subir los cambios. En la última parte de esta tarea aparecen estos conflictos al unir unas ramas.
#
# **Respuesta 7**. F. No son equivalente. Con `git clone` clonamos el repositorio X completo en un nuevo directorio, en cambio `git pull` ayuda a obtener el registro de cambios de un repositorio remoto o de una rama y esa información se une al repositorio actual. En palabras simples, `git clone`, clona un repositorio completo y `git pull` agrega lo nuevo del repositorio remota a mi repositorio local.
#
# **Respuesta 8**. Falso. `git status` permite tener una idea del estado actual del repositorio, en cambio, `git log` nos permite ver el registro de cambios, viendo los commit en el tiempo.
#
# **Respuesta 9**. V. Se puede volver a versiones anteriores. En la clase 2 de Git, el profesor Ignacio mostró que si ingresamos al terminal `git log`, podemos ver los commit que se han hecho. Podríamos elegir uno de los commit anteriores, copiar unos caracteres del hash del commit que quiero volver (mínimo 4 caracteres, en clases copio 9). En el terminal escribe `git ckeckout` + caracteres copiados del hash y volveremos por completo a la versión anterior. En la ppt aparecen otras opciones para volver a versiones anteriores como `git reset HEAD`, `git ckeckout` de una carpeta/archivo, pero en clases vimos en detalle el `git ckeckout` con el hash del commit.
#
# **Respuesta 10**. F.  `git commit` permite registrar cambios en el repositorio local. Para enviar cambios al repositorio remoto se hace con `git push`
#
# </code>

# %% [markdown]
# Por último, investigue y comente con sus palabras para qué sirven los siguientes comandos:
#
# 11. `git stash` (0.25 puntos)
# 12. `git reset`. ¿Cuál es la diferencia de este comando con `git revert`?. (0.25 puntos)

# %% [markdown]
# <code>
#
# **Respuesta 11**: `git stash`  según la página https://git-scm.com/ guarda los cambios en un directorio de trabajo sucio, en otras palabras sería almacenar temporalmente los cambios que queremos hacer en el código y uno podría volver a acceder a él después. Sirve cuando tengo que cambiar de trabajo y puedo guardar en lo que estoy trabajando actualmente en un stash sin dejarlo como cambios en mi git. Algunas características de los stash es que son locales en mi computador y no se transfieren al repositorio remoto. Los elementos guardados en los stashes se pueden enumerar con `git stash list`, puedo verlos con `git stash show`, entre otras funciones que se podrían realizar a estos stashes.
#
#
# **Respuesta 12**: `git reset` restablece el HEAD actual al estado especificado que uno indique, tomando un commit específico y restableciendo el historial para que coincida con el commit que indice, por lo que los commit que quedan entre el último commit y el commit al que reseteamos se van a eliminar cuando Git se limpie. `git revert`revierte algunos commit existentes, para ello si quiero volver a un commit específico, va a crear otro commit con el contenido del commit especifico al que quiero volver, pero con esta función no se elimina ningún commit.
#
# </code>

# %% [markdown]
# ## Parte 2: Creando una presentación personal (1.5 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/arqlNu8gyJYAAAAC/cat-cat-jumping.gif" width="150">
# </p>

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona):
# 2. Crear un repositorio con su nombre de usuario
# 3. Vincular el repositorio a su ambiente local ¿Qué comando(s) me permiten hacer esto?
# 4. Crear un archivo `readme.md` con la información que ustedes deseen compartir.
# 5. Realizar `push` con los cambios generados
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/Mezosky)
#
# **Nota: Deben trabajar todos estos puntos desde su ambiente local**
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:</code> [Presentación personal](https://github.com/ElizabethVRZ/MDS7202_1_Laboratorio_Programacion)
#
# **Respuestas**:
#
# **Respuesta 1**: [Cuenta github](https://github.com/ElizabethVRZ)
#
# **Respuesta 2**: [Repositorio curso](https://github.com/ElizabethVRZ/MDS7202_1_Laboratorio_Programacion)
#
# **Respuesta 3**: En clases lo hicimos de la siguiente manera: 1) fuimos a la página de GitHub y cliqueamos "Code". Luego se abrió opciones de copiar la dirección, había que copiar el HTTPS, 2) Luego, en el  terminal escribimos `git clone` + la dirección HTTPS copiada.
#
# **Respuesta 4**: el archivo README.md se crea al crear un nuevo repositorio en Github, en base a la clase que hizo el profesor Ignacio. Por lo que al clonar el repositorio propio, se guarda el readme.md. Luego se fue actualizando.
#
# [Presentación personal](https://github.com/ElizabethVRZ/MDS7202_1_Laboratorio_Programacion)
#
# **Respuesta 5**: esto se hace con el comando git push despues de haber guardado los commit en el readme.md.

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/YXL-0SK15j4AAAAC/dance-animals.gif" width="300">
# </p>
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (**incluya también los comandos en `Git` ocupados**):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>
# Se clono el repositorio con la siguiente línea de código:
# `git clone https://github.com/MDS7202/lab1.git` </code>

# %% [markdown]
# 2. Descomprima los archivos subidos con la tarea en U-cursos en la carpeta recién clonada de github. Una vez realizado esto, cree un archivo `.gitignore` con el cual omita la carpeta `videos` y los archivos con la extensión `.txt` exceptuando el archivo `171.txt` de la carpeta `texts`. (0.25 pts)

# %% [markdown]
# <code>Para esta pregunta usted deberá adjuntar el .gitignore creado en su repo.</code>

# %% [markdown]
# <code>
# Para hacer esto, se siguieron los siguientes pasos:
# 1. Se escribió en la consola "touch .gitignore" y se creo el archivo en la carpeta del lab1
# 2. Se abrió el archivo gitignore y se agregaron las lineas que ignoran la carpeta de video, los archivos de texto y no se ignora el 171.txt.
# 3. Luego, se escribió git add .gitignore
# 4. Se hizo el commit
# 5. Se revisó en la carpeta el archivo gitignore y tenía agregados los cambios
#
# </code>

# %% [markdown]
# 3. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también cada elemento que lo conforma. (0.25 pts)

# %% [markdown]
# Al revisar el README.md, dice que el proyecto es para emular los sonidos de animales.
#
# La estructura del proyecto remoto está conformada por 4 ramas "origin/HEAD -> origin/main;  origin/fix-ifs; origin/main ;  origin/new_features". Esto lo obtuve con el comando `git braches-r`.
#
# Si vemos un el `git log`, muestra un primer commit hecho por "seba" 22 de marzo 2023 (17:28:19 -0300). Luego, el autor "mezosky" aparece con 3 ramas (origin/new_features, origin/main, origin/HEAD). Finalmente, en mi repositorio local aparece el commit que hice al agregar el .gitiignore.
#
# Los elementos que hay se pueden ver con el comando  ls . Hay 2 archivos de extensión python (.py) que se llaman "animales.py", "main. py", el archivo "readme.md", carpetas con videos y texto (las descomprimidas).

# %% [markdown]
# 4. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# Con el comando `git log`, se puede ver que el último cambio en el repositorio local lo hice yo, agregando el .gitiignore. El último cambio en el repositorio remoto es  el realizado por mezosky, en donde separo el proyecto en modulo (23-marzo-2023).
# Las principales ramas de trabajo son   "origin/HEAD -> origin/main"; " origin/fix-if"; "  origin/ma"; "
#   origin/new_featu".
# En el commit que lei de mezosky, encontre que era informativo cuando escribió que habia separado el trabajo en  modulos, hay otro commit de Pablo Badilla que escribio fix ifs, supongo que corrigió los problemas en los if de las funciones. Pero hay unos commit sin comentarios.
# Para ver todo esto, use `git log`, `git log --all `, `git log --oneline`, `git log --all --graph --decorate --oneline` y `git log --all --graph --decorate`.  de>

# %% [markdown]
# 5. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale y explique el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>Primero, entre a la rama principal git checkout main.
# Luego, probe el código, al ingresar fox no genera error, pero al ingresar perro y gato entrega escrito el sonido pero va acompañado de un error. El error es el siguiente "/home/elizabethvrz/lab1/main.py", line 6, in <module>
#     animales(animal)
#   File "/home/elizabethvrz/lab1/animales.py", line 14, in animales
#     raise ValueError('animal no reconocido :(')
# ValueError: animal no reconocido"
#
# El problema esta en la función animales, ya que se definió solo con estos if para el perro, gato y fox, pero debería definirse solo un if y luego elif y se soluciona el problema.
# La persona que definió la función de animales fue **"mezosky"** ya que aparece que el edito el archivo animales.py de los últimos. </code>

# %% [markdown]
# 6. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# <code> Primero, revise cada commit con git show hash anteriores uno a uno. Luego para ver en detalle las diferencias, use `git diff`, `git diff --name-only`, `git diff --stat`.
# Hay diferencias especificas, como el número de lineas eliminadas o agregadas en cada uno de los commit. A modo general, muestro algunas diferencias entre cada commit.
#
#  </code>

# %% [markdown]
# | Item a comparar        | c8b1a62                        | 362fe2                                          | 25543a                         |   |   |   |   |   |   |
# |------------------------|--------------------------------|-------------------------------------------------|--------------------------------|---|---|---|---|---|---|
# | Autor                  | Seba                           |  mezosky                                        | Pablo Badilla                  |   |   |   |   |   |   |
# | Fecha                  | Wed Mar 22 17:28:19 2023 -0300 |  Thu Mar 23 21:47:34 2023 -0300                 | Thu Mar 23 22:50:49 2023 -0300 |   |   |   |   |   |   |
# | Comentarios del commit |  se agrega funcion             |  Se separa el proyecto en modulos               | fix ifs                        |   |   |   |   |   |   |
# | Archivo editado        | main.py                        | animales.py y main.py, porque separa en modulos | main.py                        |   |   |   |   |   |   |
# |                        |                                |

# %% [markdown]
# 7. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>
# Este error aparece
# `Auto-merging main.py
# CONFLICT (content): Merge conflict in main.py
# Automatic merge failed; fix conflicts and then commit the resul`
# Este mensaje dice que hay conflictos, debido a que las ramas tienen información distinta en las mismas lineas. Como se vió en clases, los conflictos hay que solucionarlos manualmente.
#
# ¿Qué parte del código podría estar ocasionando esto?
#
# Es que estoy uniendo el código que definia la función animales directo al main, entonces se agregan esas lineas. Se elimina la linea 1 con "from animales import animales" y se agregan 14 lineas. Lo anterior es lo que causa el "conflicto" que hay que solucionarlo manualmente.
# .:</code>

# %% [markdown]
# 8. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.25 pts)

# %% [markdown]
# <code> Cree la nueva rama con este comando `git checkout -b rama_nueva`
# </code>

# %%
#Código corregido
def animales(animal):#cambie el input por animal, si lo que deben ingresar en la función es el animal, es mejor ser más específico. 
    '''
    Como hace el animalito?
    '''
    animal = animal.lower()# esto lo cambie, porque es más fácil definir primero que animal es animal.lowe() y despues solo mencionar animal 
    #en los if, elif y else. 
    if animal == 'gato':
        print('miau')
    elif animal == 'perro':
        print('guau')
    elif animal == 'fox':
        print('https://www.youtube.com/watch?v=jofNR_WkoCE')
    else:
        print('Animal no reconocido :(')



if __name__ == '__main__':
    print("Ingrese el animalito para saber qué dice:")
    animal = input().strip()
    animales(animal)
# Out:
# Ingrese el animalito para saber qué dice:

# %% [markdown]
# <code>Cambie en la línea 1: input por animal.
# Cambie la línea 8: agregando el animal= animal.lower() y desplace las otras líneas hacia abajo.
# Probe la función con perro, gato, fox y ganso (que sería un animal que no esta definido ahi).</code>

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <p align="center">
#   <img src="https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif" width="350">
# </p>
